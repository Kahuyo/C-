# %% [markdown]
# <a href="https://colab.research.google.com/github/Kahuyo/C-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""5720project.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1a3GivArq0kMs5W1YXaUF6hgvurceuZz9
"""

import torch
import torchvision

print("PyTorch版本:", torch.__version__)
print("Torchvision版本:", torchvision.__version__)
print("GPU是否可用:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU型号:", torch.cuda.get_device_name(0))

# 导入必要的库
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import pandas as pd

# 定义数据预处理
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomCrop(32, padding=4),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),  # 增强数据增强
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# 下载并加载训练集
trainset = torchvision.datasets.CIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=transform_train
)
trainloader = torch.utils.data.DataLoader(
    trainset,
    batch_size=128,  # 增大batch_size加速训练
    shuffle=True,
    num_workers=2
)

# 下载并加载测试集
testset = torchvision.datasets.CIFAR10(
    root='./data',
    train=False,
    download=True,
    transform=transform_test
)
testloader = torch.utils.data.DataLoader(
    testset,
    batch_size=128,  # 统一batch_size
    shuffle=False,
    num_workers=2
)

# 定义类别名称
classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

print(f'训练集大小: {len(trainset)}')
print(f'测试集大小: {len(testset)}')
print(f'训练批次: {len(trainloader)}, 测试批次: {len(testloader)}')

# 使用ResNet-18
import torchvision.models as models

def create_resnet_model():
    model = models.resnet18(pretrained=True)

    # 修改第一层卷积，因为CIFAR-10图像较小(32x32 vs 224x224)
    model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    # 移除原来的第一个maxpool层
    model.maxpool = nn.Identity()
    # 修改最后的全连接层，输出10个类别
    model.fc = nn.Linear(model.fc.in_features, 10)

    return model

net = create_resnet_model()

# 将模型移动到GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net = net.to(device)
print(f"使用设备: {device}")

# 打印模型参数数量
total_params = sum(p.numel() for p in net.parameters())
print(f"模型总参数量: {total_params:,}")

# ====================== 优化训练配置 ======================
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(net.parameters(), lr=0.001, weight_decay=1e-4)  # 使用AdamW
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100)  # Cosine调度

# ====================== 训练函数（100 epochs） ======================
def train_model(epochs=100):
    train_losses = []
    train_accuracies = []
    test_accuracies = []
    best_accuracy = 0.0

    print(f"开始训练 {epochs} 个epochs...")
    for epoch in range(epochs):
        # 训练阶段
        net.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for i, data in enumerate(trainloader, 0):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        # 计算epoch平均损失和准确率
        epoch_loss = running_loss / len(trainloader)
        epoch_accuracy = 100.0 * correct / total

        # 更新学习率
        scheduler.step()

        # 测试阶段
        test_accuracy = test_model()

        # 保存最佳模型
        if test_accuracy > best_accuracy:
            best_accuracy = test_accuracy
            torch.save(net.state_dict(), 'best_cifar10_model.pth')

        # 保存历史数据
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_accuracy)
        test_accuracies.append(test_accuracy)

        # 每10个epoch或者最后5个epoch详细显示
        if (epoch + 1) % 10 == 0 or (epoch + 1) > epochs - 5:
            current_lr = scheduler.get_last_lr()[0]
            print(f'Epoch {epoch+1:3d}/{epochs} | '
                  f'Loss: {epoch_loss:.4f} | '
                  f'Train Acc: {epoch_accuracy:6.2f}% | '
                  f'Test Acc: {test_accuracy:6.2f}% | '
                  f'Best: {best_accuracy:6.2f}% | '
                  f'LR: {current_lr:.6f}')
        else:
            # 简略显示
            if (epoch + 1) % 5 == 0:
                print(f'Epoch {epoch+1:3d}/{epochs} | '
                      f'Loss: {epoch_loss:.4f} | '
                      f'Train Acc: {epoch_accuracy:6.2f}% | '
                      f'Test Acc: {test_accuracy:6.2f}%')

    print(f"\n训练完成！最佳测试准确率: {best_accuracy:.2f}%")
    return train_losses, train_accuracies, test_accuracies, best_accuracy

# 测试函数
def test_model():
    net.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    return accuracy

# ====================== 混淆矩阵评估函数 ======================
def evaluate_with_confusion_matrix():
    """
    使用混淆矩阵进行详细模型评估
    """
    print("\n" + "="*60)
    print("混淆矩阵评估")
    print("="*60)

    # 加载最佳模型
    net.load_state_dict(torch.load('best_cifar10_model.pth'))
    net.eval()

    all_predictions = []
    all_labels = []

    print("正在收集预测结果...")
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs, 1)

            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    predictions = np.array(all_predictions)
    true_labels = np.array(all_labels)

    # 计算整体准确率
    accuracy = 100 * np.sum(predictions == true_labels) / len(true_labels)
    print(f"✅ 整体准确率: {accuracy:.2f}%")

    # 计算混淆矩阵
    cm = confusion_matrix(true_labels, predictions)

    # 绘制混淆矩阵热力图
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=classes, yticklabels=classes,
                cbar_kws={'shrink': 0.8})
    plt.title('混淆矩阵 - CIFAR10分类结果', fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('预测标签', fontsize=12)
    plt.ylabel('真实标签', fontsize=12)
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

    # 计算各类别准确率
    print("\n📊 各类别准确率:")
    class_accuracy = {}
    for i, class_name in enumerate(classes):
        class_mask = (true_labels == i)
        if np.sum(class_mask) > 0:
            class_correct = np.sum(predictions[class_mask] == i)
            class_total = np.sum(class_mask)
            class_acc = 100 * class_correct / class_total
            class_accuracy[class_name] = class_acc
            print(f"  {class_name:8s}: {class_acc:6.2f}%")

    # 显示分类报告
    print("\n📋 详细分类报告:")
    print(classification_report(true_labels, predictions,
                              target_names=classes, digits=4))

    # 分析最难分类的类别
    print("\n🔍 最难分类的类别 (准确率最低的前3个):")
    sorted_classes = sorted(class_accuracy.items(), key=lambda x: x[1])[:3]
    for class_name, acc in sorted_classes:
        print(f"  {class_name:8s}: {acc:.2f}%")

    return accuracy, class_accuracy, cm

# ====================== 可视化训练历史 ======================
def plot_training_history(train_losses, train_accuracies, test_accuracies):
    """绘制训练历史"""
    plt.figure(figsize=(15, 5))

    plt.subplot(1, 2, 1)
    plt.plot(train_losses, 'b-', linewidth=1)
    plt.title('训练损失曲线 (100 Epochs)')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.grid(True, alpha=0.3)

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, 'r-', label='训练准确率', linewidth=1)
    plt.plot(test_accuracies, 'g-', label='测试准确率', linewidth=1)
    plt.title('准确率曲线 (100 Epochs)')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# ====================== 主程序 ======================
# 开始训练！
train_losses, train_accuracies, test_accuracies, best_accuracy = train_model(epochs=100)

# 绘制训练曲线
plot_training_history(train_losses, train_accuracies, test_accuracies)

# 执行混淆矩阵评估
final_accuracy, class_accuracy, confusion_mat = evaluate_with_confusion_matrix()

# 保存最终模型和结果
torch.save(net.state_dict(), 'final_cifar10_model_100epochs.pth')

results = {
    'train_losses': train_losses,
    'train_accuracies': train_accuracies,
    'test_accuracies': test_accuracies,
    'best_accuracy': best_accuracy,
    'final_accuracy': final_accuracy,
    'confusion_matrix': confusion_mat,
    'class_accuracy': class_accuracy
}
torch.save(results, 'training_results_100epochs.pth')

print(f"\n🎉 100个epochs训练完成！")
print(f"🏆 最佳测试准确率: {best_accuracy:.2f}%")
print(f"📊 最终测试准确率: {final_accuracy:.2f}%")
print("💾 模型和结果已保存！")
# Out:
# PyTorch版本: 2.9.0+cu126
# Torchvision版本: 0.24.0+cu126
# GPU是否可用: True
# GPU型号: Tesla T4
# 训练集大小: 50000
# 测试集大小: 10000
# 训练批次: 391, 测试批次: 79
# 使用设备: cuda:0
# 模型总参数量: 11,173,962
# 开始训练 100 个epochs...
# Epoch   5/100 | Loss: 0.2815 | Train Acc:  90.40% | Test Acc:  88.99%
# Epoch  10/100 | Loss: 0.1770 | Train Acc:  93.91% | Test Acc:  89.57% | Best:  90.47% | LR: 0.000976
# Epoch  15/100 | Loss: 0.1194 | Train Acc:  95.91% | Test Acc:  91.64%
# Epoch  20/100 | Loss: 0.0850 | Train Acc:  97.14% | Test Acc:  92.26% | Best:  92.26% | LR: 0.000905
# Epoch  25/100 | Loss: 0.0619 | Train Acc:  97.88% | Test Acc:  92.94%
# Epoch  30/100 | Loss: 0.0451 | Train Acc:  98.37% | Test Acc:  93.05% | Best:  93.05% | LR: 0.000794
# Epoch  35/100 | Loss: 0.0370 | Train Acc:  98.75% | Test Acc:  93.36%
# Epoch  40/100 | Loss: 0.0273 | Train Acc:  99.02% | Test Acc:  93.52% | Best:  93.52% | LR: 0.000655
# Epoch  45/100 | Loss: 0.0231 | Train Acc:  99.23% | Test Acc:  93.06%
# Epoch  50/100 | Loss: 0.0155 | Train Acc:  99.43% | Test Acc:  93.72% | Best:  94.00% | LR: 0.000500
# Epoch  55/100 | Loss: 0.0128 | Train Acc:  99.59% | Test Acc:  94.00%
# Epoch  60/100 | Loss: 0.0082 | Train Acc:  99.74% | Test Acc:  94.17% | Best:  94.17% | LR: 0.000345
# Epoch  65/100 | Loss: 0.0051 | Train Acc:  99.83% | Test Acc:  94.31%
# Epoch  70/100 | Loss: 0.0042 | Train Acc:  99.85% | Test Acc:  94.46% | Best:  94.46% | LR: 0.000206
# Epoch  75/100 | Loss: 0.0027 | Train Acc:  99.90% | Test Acc:  94.63%
# Epoch  80/100 | Loss: 0.0019 | Train Acc:  99.94% | Test Acc:  94.73% | Best:  94.80% | LR: 0.000095
# Epoch  85/100 | Loss: 0.0009 | Train Acc:  99.98% | Test Acc:  94.88%
# Epoch  90/100 | Loss: 0.0007 | Train Acc:  99.98% | Test Acc:  95.03% | Best:  95.06% | LR: 0.000024
# Epoch  95/100 | Loss: 0.0006 | Train Acc:  99.98% | Test Acc:  95.11%
# Epoch  96/100 | Loss: 0.0004 | Train Acc:  99.98% | Test Acc:  95.07% | Best:  95.14% | LR: 0.000004
# Epoch  97/100 | Loss: 0.0004 | Train Acc:  99.99% | Test Acc:  95.04% | Best:  95.14% | LR: 0.000002
# Epoch  98/100 | Loss: 0.0005 | Train Acc:  99.98% | Test Acc:  94.96% | Best:  95.14% | LR: 0.000001
# Epoch  99/100 | Loss: 0.0005 | Train Acc:  99.98% | Test Acc:  95.02% | Best:  95.14% | LR: 0.000000
# Epoch 100/100 | Loss: 0.0004 | Train Acc:  99.99% | Test Acc:  95.10% | Best:  95.14% | LR: 0.000000
#
# 训练完成！最佳测试准确率: 95.14%
# /tmp/ipython-input-3660657077.py:296: UserWarning: Glyph 35757 (\N{CJK UNIFIED IDEOGRAPH-8BAD}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:296: UserWarning: Glyph 32451 (\N{CJK UNIFIED IDEOGRAPH-7EC3}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:296: UserWarning: Glyph 25439 (\N{CJK UNIFIED IDEOGRAPH-635F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:296: UserWarning: Glyph 22833 (\N{CJK UNIFIED IDEOGRAPH-5931}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:296: UserWarning: Glyph 26354 (\N{CJK UNIFIED IDEOGRAPH-66F2}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:296: UserWarning: Glyph 32447 (\N{CJK UNIFIED IDEOGRAPH-7EBF}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:296: UserWarning: Glyph 20934 (\N{CJK UNIFIED IDEOGRAPH-51C6}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:296: UserWarning: Glyph 30830 (\N{CJK UNIFIED IDEOGRAPH-786E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:296: UserWarning: Glyph 29575 (\N{CJK UNIFIED IDEOGRAPH-7387}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:296: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:296: UserWarning: Glyph 35797 (\N{CJK UNIFIED IDEOGRAPH-8BD5}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 35757 (\N{CJK UNIFIED IDEOGRAPH-8BAD}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 32451 (\N{CJK UNIFIED IDEOGRAPH-7EC3}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25439 (\N{CJK UNIFIED IDEOGRAPH-635F}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 22833 (\N{CJK UNIFIED IDEOGRAPH-5931}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26354 (\N{CJK UNIFIED IDEOGRAPH-66F2}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 32447 (\N{CJK UNIFIED IDEOGRAPH-7EBF}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20934 (\N{CJK UNIFIED IDEOGRAPH-51C6}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30830 (\N{CJK UNIFIED IDEOGRAPH-786E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 29575 (\N{CJK UNIFIED IDEOGRAPH-7387}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 35797 (\N{CJK UNIFIED IDEOGRAPH-8BD5}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ============================================================
# 混淆矩阵评估
# ============================================================
# 正在收集预测结果...
# ✅ 整体准确率: 95.14%
# /tmp/ipython-input-3660657077.py:247: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:247: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:247: UserWarning: Glyph 26631 (\N{CJK UNIFIED IDEOGRAPH-6807}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:247: UserWarning: Glyph 31614 (\N{CJK UNIFIED IDEOGRAPH-7B7E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:247: UserWarning: Glyph 30495 (\N{CJK UNIFIED IDEOGRAPH-771F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:247: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:247: UserWarning: Glyph 28151 (\N{CJK UNIFIED IDEOGRAPH-6DF7}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:247: UserWarning: Glyph 28102 (\N{CJK UNIFIED IDEOGRAPH-6DC6}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:247: UserWarning: Glyph 30697 (\N{CJK UNIFIED IDEOGRAPH-77E9}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:247: UserWarning: Glyph 38453 (\N{CJK UNIFIED IDEOGRAPH-9635}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:247: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:247: UserWarning: Glyph 31867 (\N{CJK UNIFIED IDEOGRAPH-7C7B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:247: UserWarning: Glyph 32467 (\N{CJK UNIFIED IDEOGRAPH-7ED3}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3660657077.py:247: UserWarning: Glyph 26524 (\N{CJK UNIFIED IDEOGRAPH-679C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30495 (\N{CJK UNIFIED IDEOGRAPH-771F}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26631 (\N{CJK UNIFIED IDEOGRAPH-6807}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 31614 (\N{CJK UNIFIED IDEOGRAPH-7B7E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 28151 (\N{CJK UNIFIED IDEOGRAPH-6DF7}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 28102 (\N{CJK UNIFIED IDEOGRAPH-6DC6}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30697 (\N{CJK UNIFIED IDEOGRAPH-77E9}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 38453 (\N{CJK UNIFIED IDEOGRAPH-9635}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 31867 (\N{CJK UNIFIED IDEOGRAPH-7C7B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 32467 (\N{CJK UNIFIED IDEOGRAPH-7ED3}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26524 (\N{CJK UNIFIED IDEOGRAPH-679C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 📊 各类别准确率:
#   plane   :  95.90%
#   car     :  97.90%
#   bird    :  93.50%
#   cat     :  88.40%
#   deer    :  96.40%
#   dog     :  93.10%
#   frog    :  96.30%
#   horse   :  96.70%
#   ship    :  96.90%
#   truck   :  96.30%
#
# 📋 详细分类报告:
#               precision    recall  f1-score   support
#
#        plane     0.9486    0.9590    0.9538      1000
#          car     0.9732    0.9790    0.9761      1000
#         bird     0.9473    0.9350    0.9411      1000
#          cat     0.9189    0.8840    0.9011      1000
#         deer     0.9387    0.9640    0.9512      1000
#          dog     0.9163    0.9310    0.9236      1000
#         frog     0.9573    0.9630    0.9601      1000
#        horse     0.9797    0.9670    0.9733      1000
#         ship     0.9642    0.9690    0.9666      1000
#        truck     0.9698    0.9630    0.9664      1000
#
#     accuracy                         0.9514     10000
#    macro avg     0.9514    0.9514    0.9513     10000
# weighted avg     0.9514    0.9514    0.9513     10000
#
#
# 🔍 最难分类的类别 (准确率最低的前3个):
#   cat     : 88.40%
#   dog     : 93.10%
#   bird    : 93.50%
#
# 🎉 100个epochs训练完成！
# 🏆 最佳测试准确率: 95.14%
# 📊 最终测试准确率: 95.14%
# 💾 模型和结果已保存！

# %%
# -*- coding: utf-8 -*-
"""5720project.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1a3GivArq0kMs5W1YXaUF6hgvurceuZz9
"""

import torch
import torchvision

print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("GPU available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU model:", torch.cuda.get_device_name(0))

# Import necessary libraries
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import pandas as pd

# Define data preprocessing
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomCrop(32, padding=4),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),  # Enhanced data augmentation
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# Download and load training set
trainset = torchvision.datasets.CIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=transform_train
)
trainloader = torch.utils.data.DataLoader(
    trainset,
    batch_size=128,  # Increased batch_size for faster training
    shuffle=True,
    num_workers=2
)

# Download and load test set
testset = torchvision.datasets.CIFAR10(
    root='./data',
    train=False,
    download=True,
    transform=transform_test
)
testloader = torch.utils.data.DataLoader(
    testset,
    batch_size=128,  # Unified batch_size
    shuffle=False,
    num_workers=2
)

# Define class names
classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

print(f'Training set size: {len(trainset)}')
print(f'Test set size: {len(testset)}')
print(f'Training batches: {len(trainloader)}, Test batches: {len(testloader)}')

# Use ResNet-18
import torchvision.models as models

def create_resnet_model():
    model = models.resnet18(pretrained=True)

    # Modify first convolution layer for CIFAR-10 (32x32 vs 224x224)
    model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    # Remove the original first maxpool layer
    model.maxpool = nn.Identity()
    # Modify final fully connected layer for 10 classes
    model.fc = nn.Linear(model.fc.in_features, 10)

    return model

net = create_resnet_model()

# Move model to GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net = net.to(device)
print(f"Using device: {device}")

# Print model parameters
total_params = sum(p.numel() for p in net.parameters())
print(f"Total parameters: {total_params:,}")

# ====================== Optimized Training Configuration ======================
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(net.parameters(), lr=0.001, weight_decay=1e-4)  # Use AdamW
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)  # Cosine scheduler

# ====================== Training Function (200 epochs) ======================
def train_model(epochs=200):
    train_losses = []
    train_accuracies = []
    test_accuracies = []
    best_accuracy = 0.0

    print(f"Starting training for {epochs} epochs...")
    for epoch in range(epochs):
        # Training phase
        net.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for i, data in enumerate(trainloader, 0):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        # Calculate epoch average loss and accuracy
        epoch_loss = running_loss / len(trainloader)
        epoch_accuracy = 100.0 * correct / total

        # Update learning rate
        scheduler.step()

        # Testing phase
        test_accuracy = test_model()

        # Save best model
        if test_accuracy > best_accuracy:
            best_accuracy = test_accuracy
            torch.save(net.state_dict(), 'best_cifar10_model.pth')

        # Save history data
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_accuracy)
        test_accuracies.append(test_accuracy)

        # Detailed display every 10 epochs or last 5 epochs
        if (epoch + 1) % 10 == 0 or (epoch + 1) > epochs - 5:
            current_lr = scheduler.get_last_lr()[0]
            print(f'Epoch {epoch+1:3d}/{epochs} | '
                  f'Loss: {epoch_loss:.4f} | '
                  f'Train Acc: {epoch_accuracy:6.2f}% | '
                  f'Test Acc: {test_accuracy:6.2f}% | '
                  f'Best: {best_accuracy:6.2f}% | '
                  f'LR: {current_lr:.6f}')
        else:
            # Brief display
            if (epoch + 1) % 5 == 0:
                print(f'Epoch {epoch+1:3d}/{epochs} | '
                      f'Loss: {epoch_loss:.4f} | '
                      f'Train Acc: {epoch_accuracy:6.2f}% | '
                      f'Test Acc: {test_accuracy:6.2f}%')

    print(f"\nTraining completed! Best test accuracy: {best_accuracy:.2f}%")
    return train_losses, train_accuracies, test_accuracies, best_accuracy

# Test function
def test_model():
    net.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    return accuracy

# ====================== Confusion Matrix Evaluation Function ======================
def evaluate_with_confusion_matrix():
    """
    Detailed model evaluation using confusion matrix
    """
    print("\n" + "="*60)
    print("Confusion Matrix Evaluation")
    print("="*60)

    # Load best model
    net.load_state_dict(torch.load('best_cifar10_model.pth'))
    net.eval()

    all_predictions = []
    all_labels = []

    print("Collecting predictions...")
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs, 1)

            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    predictions = np.array(all_predictions)
    true_labels = np.array(all_labels)

    # Calculate overall accuracy
    accuracy = 100 * np.sum(predictions == true_labels) / len(true_labels)
    print(f"✅ Overall Accuracy: {accuracy:.2f}%")

    # Calculate confusion matrix
    cm = confusion_matrix(true_labels, predictions)

    # Plot confusion matrix heatmap
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=classes, yticklabels=classes,
                cbar_kws={'shrink': 0.8})
    plt.title('Confusion Matrix - CIFAR10 Classification Results', fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('Predicted Labels', fontsize=12)
    plt.ylabel('True Labels', fontsize=12)
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

    # Calculate per-class accuracy
    print("\n📊 Per-Class Accuracy:")
    class_accuracy = {}
    for i, class_name in enumerate(classes):
        class_mask = (true_labels == i)
        if np.sum(class_mask) > 0:
            class_correct = np.sum(predictions[class_mask] == i)
            class_total = np.sum(class_mask)
            class_acc = 100 * class_correct / class_total
            class_accuracy[class_name] = class_acc
            print(f"  {class_name:8s}: {class_acc:6.2f}%")

    # Show classification report
    print("\n📋 Detailed Classification Report:")
    print(classification_report(true_labels, predictions,
                              target_names=classes, digits=4))

    # Analyze hardest to classify classes
    print("\n🔍 Hardest to Classify Classes (Bottom 3):")
    sorted_classes = sorted(class_accuracy.items(), key=lambda x: x[1])[:3]
    for class_name, acc in sorted_classes:
        print(f"  {class_name:8s}: {acc:.2f}%")

    return accuracy, class_accuracy, cm

# ====================== Training History Visualization ======================
def plot_training_history(train_losses, train_accuracies, test_accuracies):
    """Plot training history"""
    plt.figure(figsize=(15, 5))

    plt.subplot(1, 2, 1)
    plt.plot(train_losses, 'b-', linewidth=1)
    plt.title('Training Loss Curve (100 Epochs)')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.grid(True, alpha=0.3)

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, 'r-', label='Training Accuracy', linewidth=1)
    plt.plot(test_accuracies, 'g-', label='Test Accuracy', linewidth=1)
    plt.title('Accuracy Curve (100 Epochs)')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# ====================== Main Program ======================
# Start training!
train_losses, train_accuracies, test_accuracies, best_accuracy = train_model(epochs=200)

# Plot training curves
plot_training_history(train_losses, train_accuracies, test_accuracies)

# Execute confusion matrix evaluation
final_accuracy, class_accuracy, confusion_mat = evaluate_with_confusion_matrix()

# Save final model and results
torch.save(net.state_dict(), 'final_cifar10_model_200epochs.pth')

results = {
    'train_losses': train_losses,
    'train_accuracies': train_accuracies,
    'test_accuracies': test_accuracies,
    'best_accuracy': best_accuracy,
    'final_accuracy': final_accuracy,
    'confusion_matrix': confusion_mat,
    'class_accuracy': class_accuracy
}
torch.save(results, 'training_results_200epochs.pth')

print(f"\n 200 epochs training completed!")
print(f" Best Test Accuracy: {best_accuracy:.2f}%")
print(f" Final Test Accuracy: {final_accuracy:.2f}%")
print(" Models and results saved!")
# Out:
# PyTorch version: 2.9.0+cu126
# Torchvision version: 0.24.0+cu126
# GPU available: True
# GPU model: Tesla T4
# Training set size: 50000
# Test set size: 10000
# Training batches: 391, Test batches: 79
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Using device: cuda:0
# Total parameters: 11,173,962
# Starting training for 200 epochs...
# Epoch   5/200 | Loss: 0.2845 | Train Acc:  90.31% | Test Acc:  87.97%
# Epoch  10/200 | Loss: 0.1791 | Train Acc:  93.87% | Test Acc:  90.38% | Best:  90.38% | LR: 0.000994
# Epoch  15/200 | Loss: 0.1258 | Train Acc:  95.66% | Test Acc:  91.94%
# Epoch  20/200 | Loss: 0.0885 | Train Acc:  96.96% | Test Acc:  91.68% | Best:  92.61% | LR: 0.000976
# Epoch  25/200 | Loss: 0.0709 | Train Acc:  97.55% | Test Acc:  92.51%
# Epoch  30/200 | Loss: 0.0587 | Train Acc:  97.98% | Test Acc:  92.68% | Best:  92.68% | LR: 0.000946
# Epoch  35/200 | Loss: 0.0469 | Train Acc:  98.33% | Test Acc:  92.80%
# Epoch  40/200 | Loss: 0.0402 | Train Acc:  98.70% | Test Acc:  93.05% | Best:  93.12% | LR: 0.000905
# Epoch  45/200 | Loss: 0.0340 | Train Acc:  98.84% | Test Acc:  93.38%
# Epoch  50/200 | Loss: 0.0286 | Train Acc:  99.00% | Test Acc:  93.23% | Best:  93.79% | LR: 0.000854
# Epoch  55/200 | Loss: 0.0254 | Train Acc:  99.13% | Test Acc:  92.97%
# Epoch  60/200 | Loss: 0.0211 | Train Acc:  99.29% | Test Acc:  93.05% | Best:  93.79% | LR: 0.000794
# Epoch  65/200 | Loss: 0.0195 | Train Acc:  99.38% | Test Acc:  93.63%
# Epoch  70/200 | Loss: 0.0169 | Train Acc:  99.43% | Test Acc:  94.06% | Best:  94.06% | LR: 0.000727
# Epoch  75/200 | Loss: 0.0147 | Train Acc:  99.51% | Test Acc:  93.60%
# Epoch  80/200 | Loss: 0.0154 | Train Acc:  99.50% | Test Acc:  93.58% | Best:  94.06% | LR: 0.000655
# Epoch  85/200 | Loss: 0.0120 | Train Acc:  99.58% | Test Acc:  93.77%
# Epoch  90/200 | Loss: 0.0108 | Train Acc:  99.64% | Test Acc:  93.89% | Best:  94.06% | LR: 0.000578
# Epoch  95/200 | Loss: 0.0071 | Train Acc:  99.77% | Test Acc:  93.94%
# Epoch 100/200 | Loss: 0.0081 | Train Acc:  99.71% | Test Acc:  93.98% | Best:  94.15% | LR: 0.000500
# Epoch 105/200 | Loss: 0.0062 | Train Acc:  99.79% | Test Acc:  93.82%
# Epoch 110/200 | Loss: 0.0046 | Train Acc:  99.86% | Test Acc:  94.10% | Best:  94.28% | LR: 0.000422
# Epoch 115/200 | Loss: 0.0043 | Train Acc:  99.85% | Test Acc:  94.08%
# Epoch 120/200 | Loss: 0.0039 | Train Acc:  99.87% | Test Acc:  94.28% | Best:  94.33% | LR: 0.000345
# Epoch 125/200 | Loss: 0.0028 | Train Acc:  99.91% | Test Acc:  94.47%
# Epoch 130/200 | Loss: 0.0026 | Train Acc:  99.91% | Test Acc:  94.60% | Best:  94.60% | LR: 0.000273
# Epoch 135/200 | Loss: 0.0024 | Train Acc:  99.93% | Test Acc:  94.74%
# Epoch 140/200 | Loss: 0.0012 | Train Acc:  99.95% | Test Acc:  94.54% | Best:  94.79% | LR: 0.000206
# Epoch 145/200 | Loss: 0.0014 | Train Acc:  99.96% | Test Acc:  94.60%
# Epoch 150/200 | Loss: 0.0010 | Train Acc:  99.96% | Test Acc:  94.56% | Best:  94.79% | LR: 0.000146
# Epoch 155/200 | Loss: 0.0010 | Train Acc:  99.97% | Test Acc:  94.76%
# Epoch 160/200 | Loss: 0.0006 | Train Acc:  99.98% | Test Acc:  94.67% | Best:  94.91% | LR: 0.000095
# Epoch 165/200 | Loss: 0.0009 | Train Acc:  99.97% | Test Acc:  94.80%
# Epoch 170/200 | Loss: 0.0003 | Train Acc:  99.99% | Test Acc:  94.85% | Best:  94.95% | LR: 0.000054
# Epoch 175/200 | Loss: 0.0003 | Train Acc:  99.99% | Test Acc:  94.94%
# Epoch 180/200 | Loss: 0.0002 | Train Acc: 100.00% | Test Acc:  95.00% | Best:  95.01% | LR: 0.000024
# Epoch 185/200 | Loss: 0.0003 | Train Acc:  99.99% | Test Acc:  94.96%
# Epoch 190/200 | Loss: 0.0002 | Train Acc: 100.00% | Test Acc:  94.93% | Best:  95.02% | LR: 0.000006
# Epoch 195/200 | Loss: 0.0003 | Train Acc:  99.99% | Test Acc:  94.91%
# Epoch 196/200 | Loss: 0.0001 | Train Acc: 100.00% | Test Acc:  95.08% | Best:  95.08% | LR: 0.000001
# Epoch 197/200 | Loss: 0.0001 | Train Acc: 100.00% | Test Acc:  94.95% | Best:  95.08% | LR: 0.000001
# Epoch 198/200 | Loss: 0.0001 | Train Acc: 100.00% | Test Acc:  94.92% | Best:  95.08% | LR: 0.000000
# Epoch 199/200 | Loss: 0.0001 | Train Acc: 100.00% | Test Acc:  95.01% | Best:  95.08% | LR: 0.000000
# Epoch 200/200 | Loss: 0.0002 | Train Acc:  99.99% | Test Acc:  94.98% | Best:  95.08% | LR: 0.000000
#
# Training completed! Best test accuracy: 95.08%
# ============================================================
# Confusion Matrix Evaluation
# ============================================================
# Collecting predictions...
# ✅ Overall Accuracy: 95.08%
# 📊 Per-Class Accuracy:
#   plane   :  96.30%
#   car     :  97.90%
#   bird    :  93.30%
#   cat     :  90.10%
#   deer    :  96.40%
#   dog     :  91.50%
#   frog    :  96.90%
#   horse   :  96.10%
#   ship    :  96.20%
#   truck   :  96.10%
#
# 📋 Detailed Classification Report:
#               precision    recall  f1-score   support
#
#        plane     0.9450    0.9630    0.9539      1000
#          car     0.9722    0.9790    0.9756      1000
#         bird     0.9520    0.9330    0.9424      1000
#          cat     0.8912    0.9010    0.8961      1000
#         deer     0.9314    0.9640    0.9474      1000
#          dog     0.9242    0.9150    0.9196      1000
#         frog     0.9719    0.9690    0.9705      1000
#        horse     0.9846    0.9610    0.9727      1000
#         ship     0.9678    0.9620    0.9649      1000
#        truck     0.9697    0.9610    0.9653      1000
#
#     accuracy                         0.9508     10000
#    macro avg     0.9510    0.9508    0.9508     10000
# weighted avg     0.9510    0.9508    0.9508     10000
#
#
# 🔍 Hardest to Classify Classes (Bottom 3):
#   cat     : 90.10%
#   dog     : 91.50%
#   bird    : 93.30%
#
#  200 epochs training completed!
#  Best Test Accuracy: 95.08%
#  Final Test Accuracy: 95.08%
#  Models and results saved!
